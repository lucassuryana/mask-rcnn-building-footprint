# %%
from arcgis.learn import MaskRCNN, prepare_data
# Out:
# PROJ: proj_create_from_database: Cannot find proj.db

# %%
data = prepare_data(r'C:\\Users\\lesuryana\\Documents\\Kerja\\Natural Resources\\Utilities\\Training Sample Tangerang', 
                    batch_size=1, 
                    chip_size=64)

# %%
data.show_batch(rows=1)

# %%
model = MaskRCNN(data)

# %%
model.fit(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.057691</td>
#       <td>1.917629</td>
#       <td>02:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.save('E1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-88ac1e57edab> in <module>
# ----> 1 model.save('E1')
#
# ~\AppData\Local\ESRI\conda\envs\deeplearning\lib\site-packages\arcgis\learn\models\_arcgis_model.py in save(self, name_or_path, framework, publish, gis, **kwargs)
#     664         =====================   ===========================================
#     665         """
# --> 666         return self._save(name_or_path, framework=framework, publish=publish, gis=gis, **kwargs)
#     667
#     668     def load(self, name_or_path):
#
# ~\AppData\Local\ESRI\conda\envs\deeplearning\lib\site-packages\arcgis\learn\models\_arcgis_model.py in _save(self, name_or_path, framework, zip_files, save_html, publish, gis, **kwargs)
#     540
#     541             if save_html:
# ...
